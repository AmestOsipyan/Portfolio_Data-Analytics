# %% [markdown]
# # Приоритизация гипотез и анализ А/В теста

# %% [markdown]
# **Цели и задачи проекта:**
# Приоретизация подготовленных гипотез и анализ А/В теста для увеличения выручки интернет-магазина.
#
# **План работы:**
# 1. Приоретизация 9 гипотез с примением фреймворков ICE и RICE.
# 2. Анализ А/В теста

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Приоретизация-гипотез" data-toc-modified-id="Приоретизация-гипотез-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Приоретизация гипотез</a></span><ul class="toc-item"><li><span><a href="#Загрузим-и-изучим-данные" data-toc-modified-id="Загрузим-и-изучим-данные-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузим и изучим данные</a></span></li><li><span><a href="#Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета" data-toc-modified-id="Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета</a></span></li><li><span><a href="#Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета" data-toc-modified-id="Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета</a></span></li><li><span><a href="#Изменения-приоритизации-гипотез-при-применении-RICE-вместо-ICE" data-toc-modified-id="Изменения-приоритизации-гипотез-при-применении-RICE-вместо-ICE-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Изменения приоритизации гипотез при применении RICE вместо ICE</a></span></li></ul></li><li><span><a href="#Анализ-А/В-теста" data-toc-modified-id="Анализ-А/В-теста-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ А/В теста</a></span><ul class="toc-item"><li><span><a href="#Загрузим-и-изучим-данные" data-toc-modified-id="Загрузим-и-изучим-данные-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузим и изучим данные</a></span></li><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам.-Выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-Выводы-и-предположения.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам. Выводы и предположения.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам.-Выводы-и-предположения" data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам.-Выводы-и-предположения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам. Выводы и предположения</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Выводы-и-предположения" data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Выводы-и-предположения-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Выводы и предположения</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.--Выводы-и-предположения" data-toc-modified-id="Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.--Выводы-и-предположения-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Построим график кумулятивного среднего количества заказов на посетителя по группам.  Выводы и предположения</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Выводы-и-предположения." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Выводы-и-предположения.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Выводы и предположения.</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям.-Выводы-и-предположения" data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям.-Выводы-и-предположения-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям. Выводы и предположения</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберим-границу-для-определения-аномальных-пользователей" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберим-границу-для-определения-аномальных-пользователей-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберим границу для определения аномальных пользователей</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов.-Выводы-и-предположения" data-toc-modified-id="Построим-точечный-график-стоимостей-заказов.-Выводы-и-предположения-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов. Выводы и предположения</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберим-границу-для-определения-аномальных-заказов" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберим-границу-для-определения-аномальных-заказов-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберим границу для определения аномальных заказов</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Выводы-и-предположения" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Выводы-и-предположения-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Выводы-и-предположения.-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Выводы-и-предположения" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Выводы-и-предположения-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Выводы-и-предположения" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Выводы-и-предположения-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения</a></span></li><li><span><a href="#Решение-по-результатам-теста" data-toc-modified-id="Решение-по-результатам-теста-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Решение по результатам теста</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Приоретизация гипотез

# %% [markdown]
# ### Загрузим и изучим данные

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

plt.rcParams["figure.figsize"] = (12,9)

# %%
try:
    data_hypothesis = pd.read_csv('/datasets/hypothesis.csv')
except:
    data_hypothesis = pd.read_csv('c:/users/user/Desktop/datasets/hypothesis.csv')

# %%
pd.options.display.max_colwidth = 150
display(data_hypothesis)
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# В таблице представлено 9 гипотез. Каждому из них присвоены параметры Reach, Impact, Confidence, Efforts. Есть все данные для дальнейшей приоретизации гипотез.

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета

# %% [markdown]
# Применяем один из самых популярных методов приоритизации - метод ICE. В рамках данного метода в удобных шкалах (например от 0 до 10 или в числах ряда Фибоначчи) оцениваются следующие параметры:
#
# 1. Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# 2. Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# 3. Efforts — сколько стоит протестировать эту гипотезу.
#
# И далее по формуле **(Impact * Confidence)/ Efforts** рассчитываются значения ICE для всех гипотез. Чем выше значение ICE, тем выше приоритет гипотезы.
#
# В наших данных работа по оценке параметров проведа. Мы можем приступить к расчету значений ICE  по формуле.

# %%
data_hypothesis['ICE'] = ((data_hypothesis['Impact']*data_hypothesis['Confidence'])/data_hypothesis['Efforts']).round(2)
display(data_hypothesis[['Hypothesis', 'ICE']].sort_values(by='ICE', ascending=False))
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# **Наиболее перспективные гипотезы по ICE - 8, 0, 7, 6, 2**

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета

# %% [markdown]
# Существует модифицированный метод ICE - это метод RICE. Он отличается от предыдущего метода тем, что в дополнение ко всем параметрам учитывает очень важный параметр - Reach, условно - охват. Данный параметр позволяет оценить скольких пользователей затронет изменение, которое предлагается внести в рамках гипотезы.
#
# Значение RICE рассчитывается по формуле **(Reach * Impact * Confidence) / Efforts**. Чем выше значение RICE, тем выше приоритет гипотезы.
#
# В наших данных работа по оценке параметров проведа. Мы можем приступить к расчету значений RICE по формуле.

# %%
data_hypothesis['RICE'] = ((data_hypothesis['Reach']*data_hypothesis['Impact']*data_hypothesis['Confidence'])/data_hypothesis['Efforts']).round(2)
display(data_hypothesis[['Hypothesis', 'RICE']].sort_values(by='RICE', ascending=False))
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# **Наиболее перспективные гипотезы по RICE - 7, 2, 0, 6, 8**

# %% [markdown]
# ### Изменения приоритизации гипотез при применении RICE вместо ICE

# %% [markdown]
# Наиболее перспективные гипотезы по ICE - 8, 0, 7, 6, 2
#
# Наиболее перспективные гипотезы по RICE - 7, 2, 0, 6, 8
#
# Гипотезы 7 и 2 вышли на лидирующие позиции по RICE в связи с высоким показателем охвата (Reach 10 и 8 соответственно). Лидирующая по ICE гипотеза 8 уступила свои позиции остальным гипотезам по фреймворку RICE, так как показатель охвата данной гипотезы составляет всего 1.

# %% [markdown]
# ## Анализ А/В теста

# %% [markdown]
# ### Загрузим и изучим данные

# %%
try:
    orders = pd.read_csv('/datasets/orders.csv')
except:
    orders = pd.read_csv('c:/users/user/Desktop/datasets/orders.csv')
    
try:
    visitors = pd.read_csv('/datasets/visitors.csv')
except:
    visitors = pd.read_csv('c:/users/user/Desktop/datasets/visitors.csv')
    
display(orders.head())
print(orders.info())
print('*'*100)
display(visitors.head())
print(visitors.info())
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
# ****************************************************************************************************
#          date group  visitors
# 0  2019-08-01     A       719
# ...

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
visitors.duplicated().sum()
# Out:
# 0

# %%
orders.isna().sum()
# Out:
# transactionId    0
# visitorId        0
# date             0
# revenue          0
# group            0
# dtype: int64

# %%
visitors.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# Предоставлены 2 таблицы с данными по заказам (orders) и количеству посетителей (visitors).
#
# Таблица orders включает следующие данные:
# 1. transactionId — идентификатор заказа;
# 2. visitorId — идентификатор пользователя, совершившего заказ;
# 3. date — дата, когда был совершён заказ;
# 4. revenue — выручка заказа;
# 5. group — группа A/B-теста, в которую попал заказ.
#
# Таблица visitors включает следующие данные:
# 1. date — дата;
# 2. group — группа A/B-теста;
# 3. visitors — количество пользователей в указанную дату в указанной группе A/B-теста
#
# **Явных дубликатов в таблицах не обнаружено.**
#
# **Пропусков в таблицах не обнаружно.**

# %%
print(orders['group'].unique())
# Out:
# ['B' 'A']

# %%
ordersAgroup = orders[orders['group'] == 'A']['visitorId']
ordersBgroup = orders[orders['group'] == 'B']['visitorId']

# %%
print(len(ordersAgroup))
print(ordersAgroup.nunique())
# Out:
# 557
# 503

# %%
print(len(ordersBgroup))
print(ordersBgroup.nunique())
# Out:
# 640
# 586

# %%
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %%
print('Дата начала теста:', orders['date'].min())
print('Дата окончания теста:', orders['date'].max())
# Out:
# Дата начала теста: 2019-08-01 00:00:00
# Дата окончания теста: 2019-08-31 00:00:00

# %%
orders_grouped = orders.groupby('visitorId', as_index=False)['group'].nunique()
print('Количество пользователей, которые попали и в группу А и в группу В:', len(orders_grouped[orders_grouped['group'] >1]))
# Out:
# Количество пользователей, которые попали и в группу А и в группу В: 58

# %%
print('Количество пользователей, которые попали и в группу А и в группу В, составляет {0:.2f} % от общего количества пользователей'.format(
    len(orders_grouped[orders_grouped['group'] >1])*100/orders['visitorId'].nunique()))
# Out:
# Количество пользователей, которые попали и в группу А и в группу В, составляет 5.63 % от общего количества пользователей

# %% [markdown]
# В тесте участвуют 2 группы - А и В. Тест парный.
#
# Дата начала теста 2019-08-01
# Дата окончания теста 2019-08-31
#
# Количество уникальных потребителей в группе А - 503
# Количество уникальных потребителей в группе В - 586
#
# 5.63% пользователей в ходе теста попали в обе группы. Данный уровень "загрязненности" теста можем считать допустимым и некритичным. В дальнейшем рекомендуем не превышать уровень "загряжненности" более 5%.
# В данных мы не удаляем повторяющихся пользователей, так как их данные агрегированы и содержатся в таблице visitors.

# %% [markdown]
# Есть все данные для проведения анализа А/В теста.

# %% [markdown]
# ### Построим график кумулятивной выручки по группам. Выводы и предположения.

# %%
datesgroup = orders[['date', 'group']].drop_duplicates()

# %%
ordersAggregated = datesgroup.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
.agg({'date': 'max', 'group': 'max', 'visitorId': 'nunique', 'transactionId': 'nunique', 'revenue': 'sum'}), \
                                    axis=1).sort_values(by=['date', 'group'])

display(ordersAggregated.head())
# Out:
#           date group  visitorId  transactionId  revenue
# 55  2019-08-01     A         20             24   148579
# 66  2019-08-01     B         20             21   101217
# 175 2019-08-02     A         38             44   242401
# 173 2019-08-02     B         43             45   266748
# 291 2019-08-03     A         62             68   354874

# %%
visitorsAggregated = datesgroup.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])]\
                                     .agg({'date': 'max', 'group': 'max', 'visitors': 'sum'}), axis=1).sort_values(by=['date', 'group'])

display(visitorsAggregated.head())
# Out:
#           date group  visitors
# 55  2019-08-01     A       719
# 66  2019-08-01     B       713
# 175 2019-08-02     A      1338
# 173 2019-08-02     B      1294
# 291 2019-08-03     A      1845

# %%
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'buyers', 'orders', 'revenue', 'visitors']
display(cumulativeData.head())
# Out:
#         date group  buyers  orders  revenue  visitors
# 0 2019-08-01     A      20      24   148579       719
# 1 2019-08-01     B      20      21   101217       713
# 2 2019-08-02     A      38      44   242401      1338
# 3 2019-08-02     B      43      45   266748      1294
# 4 2019-08-03     A      62      68   354874      1845

# %%
cumulativeRevenueA = cumulativeData[cumulativeData['group'] == 'A'][['date', 'revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group'] == 'B'][['date', 'revenue', 'orders']]

# %%
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.legend()
plt.title('График кумулятивной выручки по группам' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Дата', fontsize=10)
plt.ylabel('Выручка', fontsize=10);

# %% [markdown]
# **Вывод**
#
# График демонстрирует увеличение выручки у группы В по сравнению с группой А. Причем до определенного момента эта разница небольшая, потом происходит резкий скачок разницы выручки между двумя группами, который в дальнейшем держится на протяжении наблюдаемого периода.
#
# Такое поведение на выбросы не похоже. Возможно, изменения в группе В требуют времени для реакции со стороны потребителей, поэтому результат в виде резкого скачка выручки проявился через определенное время.

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам. Выводы и предположения

# %%
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.legend()
plt.title('График кумулятивного среднего чека по группам' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Дата', fontsize=10)
plt.ylabel('Средний чек', fontsize=10);

# %% [markdown]
# **Вывод**
#
# Средний чек неравномерный. До середины теста видим увеличение и падение среднего чека в обоих группах. Возможно это связано с выбросами некоторыми: например, крупные заказы. После наблюдается все тот ж сильный скачок, что и в графике по выручке, но уже в среднем чеке в группе В, который в дальнейшем идет на медленное убывание.
#
# В дальнейшем анализе мы избавимся от аномальных значений, которые могли привести к таким картинам. Хотя возможно, что изменения в группе В результативные.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Выводы и предположения

# %%
McumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
plt.plot(McumulativeRevenue['date'], (McumulativeRevenue['revenueB']/McumulativeRevenue['ordersB'])/(McumulativeRevenue['revenueA']/McumulativeRevenue['ordersA'])-1)
plt.axhline(y=0, color='pink', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего чека В к А' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Дата', fontsize=10)
plt.ylabel('Изменение среднего чека', fontsize=10);

# %% [markdown]
# **Вывод**
#
# График изменения среднего чека между сегментами резкие скачки и резкие понижения. Скорее всего это связано с выбросами и крупными заказами. Данные аномалии в дальнейшем исследуем.

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам.  Выводы и предположения

# %%
cumulativeData['orderspervisitor'] = cumulativeData['orders']/cumulativeData['visitors']
cumulativeOrdersperVisitorA = cumulativeData[cumulativeData['group'] == 'A']
cumulativeOrdersperVisitorB = cumulativeData[cumulativeData['group'] == 'B']

plt.plot(cumulativeOrdersperVisitorA['date'], cumulativeOrdersperVisitorA['orderspervisitor'], label='A')
plt.plot(cumulativeOrdersperVisitorB['date'], cumulativeOrdersperVisitorB['orderspervisitor'], label='B')
plt.legend()
plt.title('График кумулятивного среднего количества заказов на посетителя по группам' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Дата', fontsize=10)
plt.ylabel('Ср. кол-во заказов на посетителя', fontsize=10);

# %% [markdown]
# **Вывод**
#
# В начале теста график скачкообразный, у группы А показатели выше. В дальнейшем видим уверенный рост среднего количества заказов на посетителя у группы В и резкое снижение показателей у группы А. В любом случае значения не выравниваются в обоих группах и сохраняют скачкообразный вид на достигнутых уровнях. Необходимо очистить данные от аномальных значений и еще раз проверить показатели.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Выводы и предположения.

# %%
McumulativeOrdersperVisitor = cumulativeOrdersperVisitorA.merge(cumulativeOrdersperVisitorB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
plt.plot(McumulativeOrdersperVisitor['date'], McumulativeOrdersperVisitor['orderspervisitorB']/McumulativeOrdersperVisitor['orderspervisitorA'] -1)
plt.axhline(y=0, color='pink', linestyle='--')
plt.axhline(y=-0.1, color='grey', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего количества заказов на посетителя  B к A' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Дата', fontsize=10)
plt.ylabel('Изменения среднего количества заказов на посетителя', fontsize=10);

# %% [markdown]
# **Вывод**
#
# В начале теста изменение среднего количества заказов на посетителя у группы В относительно группы А резко вырастает, а затем также резко снижается. После чего мы видим хороший рост относительного изменения кумулятивного среднего количества заказов на посетителя и сохранение этого уровня до конца теста. Однако на этом же уровне показатели нестабильны и подвержены скачкам и падениям.

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям. Выводы и предположения

# %%
data = orders.groupby('visitorId', as_index=False)['transactionId'].nunique()
data.columns=['users', 'orders']

plt.scatter(data['users'], data['orders'])
plt.title('Точечный график количества заказов по пользователям' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Пользователи', fontsize=10)
plt.ylabel('Количество заказов', fontsize=10);

# %% [markdown]
# **Вывод**
#
# По графику можно установить, что нормой является до 2-х заказов на 1 пользователя. Границами аномального количества заказов являются от 3-х до 11-ти.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберим границу для определения аномальных пользователей

# %%
print(np.percentile(data['orders'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# **Вывод**
#
# Не более 5% пользователей оформляли больше 2-х заказов. И 1% пользователей заказывали более 4-х раз.
#
# Предыдущий вывод подвтердился. Цеелесообразно принять за верхнюю границу числа заказов - 2. По этой границе отсеиваем остальные аномальные значения.

# %% [markdown]
# ### Построим точечный график стоимостей заказов. Выводы и предположения

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))
plt.scatter(x_values, orders['revenue'])
plt.title('Точечный график стоимостей заказов' + "\n", fontsize=15, color='darkblue')
plt.xlabel('Количество', fontsize=10)
plt.ylabel('Стоимость заказов', fontsize=10);

# %% [markdown]
# **Вывод**
#
# По графику нормой заказов являются заказы со стоимостью до 10000 руб. (0.1). Встречаются аномальные значения 20000 и 130000 руб.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберим границу для определения аномальных заказов

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# **Вывод**
#
# Не более 5% пользователей оформляли заказы на сумму более 28000руб. И 1% пользователей заказывали на сумму более 58233 руб.
#
# Целесообразно принять за верхнюю стоимости заказов - 28000 руб. По этой границе отсеиваем остальные аномальные значения.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения

# %% [markdown]
# Сформулируем гипотезы:
#
# **Нулевая:** различий в среднем количестве заказов на посетителя между группами А и В нет (*по "сырым" данным*).
#
# **Альтернативная:** различия в среднем количестве заказов на посетителя между группами А и В есть (*по "сырым" данным*).
#
# Критический уровень статистической значимости здесь и далее устанавливаем 0.05
#
# Применяем тест, основанный на структурном подходе, U-критерий Манна-Уитни (*В случаях, когда есть большие выбросы в данных, целесообразнее применять непараметрические тесты*). Тест определяет, одинаково ли вероятно, что любое случайно выбранное наблюдение из одной выборки будет больше или меньше, чем выборка из другого распределения.
#
# Критерий, по которому мы осуществляем проверку здесь и далее - значение р (p-value).

# %%
ordersByUsersA = orders[orders['group'] == 'A'].groupby('visitorId', as_index=False)['transactionId'].nunique()
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = orders[orders['group'] == 'B'].groupby('visitorId', as_index=False)['transactionId'].nunique()
ordersByUsersB.columns = ['userId', 'orders']

# %%
sampleA = pd.concat([ordersByUsersA['orders'], pd.Series(0, index=np.arange(visitorsAggregated[visitorsAggregated['group']=='A']['visitors'].max() - len(ordersByUsersA['orders'])), name = 'orders')], axis=0)

sampleB = pd.concat([ordersByUsersB['orders'], pd.Series(0, index=np.arange(visitorsAggregated[visitorsAggregated['group']=='B']['visitors'].max() - len(ordersByUsersA['orders'])), name = 'orders')], axis=0)

# %%
print('Р-value {0:.3f}'.format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print('Относительный прирост среднего числа заказов группы B к группе А {0:.3f}'.format(sampleB.mean()/sampleA.mean() -1))
# Out:
# Р-value 0.020
# Относительный прирост среднего числа заказов группы B к группе А 0.133

# %% [markdown]
# **Вывод**
#
# По "сырым" данным есть различия по среднему числу заказов на посетителя в группах А и В. P-value 0.02 менее 0.05.
#
# Значит, **нулевую гипотезу** о том, что статистически значимых различий в среднем числе заказов между группами нет, мы **отвергаем.**
#
# Также видим относительный выигрыш группы B. Он равен 13.3%. Что является положительным результатом.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.

# %% [markdown]
# Сформулируем гипотезы:
#
# **Нулевая:** различий в среднем чеке заказа между группами А и В нет (*по "сырым" данным*).
#
# **Альтернативная:** различия в среднем чеке заказа между группами А и В есть (*по "сырым" данным*).

# %%
print('P-value {0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('Относительный прирост среднего чека заказа группы B к группе А {0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean() - 1))
# Out:
# P-value 0.729
# Относительный прирост среднего чека заказа группы B к группе А 0.259

# %% [markdown]
# **Вывод**
#
# P-value составляет 0,729, что значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет.
#
# В то же время средний чек группы B ощутимо выше среднего чека группы A - почти на 26%.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения

# %% [markdown]
# По предыдущим расчетам мы установили, что 95-й и 99-й перцентили средних чеков равны 28000 и 58233.20 руб. А 95-й и 99-й перцентили количества заказов на одного пользователя равны 2 и 4 заказа на пользователя.
#
# Примем за аномальных пользователей тех, кто совершил больше 2-х заказов или совершил заказ дороже 28 000 рублей. Так мы уберём 5% пользователей с наибольшим числом заказов и 5% пользователей с дорогими заказами.

# %% [markdown]
# Узнаем, сколько всего аномальных пользователей

# %%
usersManyOrders = pd.concat([ordersByUsersA[ordersByUsersA['orders'] > np.percentile(data['orders'], 95)]['userId'], ordersByUsersB[ordersByUsersB['orders'] > 2]['userId']], axis=0)

usersExpOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], 95)]['visitorId']

abnormalUsers = pd.concat([usersManyOrders, usersExpOrders], axis=0).drop_duplicates().sort_values()

print(abnormalUsers.head())
print(abnormalUsers.shape[0])
# Out:
# 1099    148427295
# 18      199603092
# 928     204675465
# 23      237748145
# 37      249864742
# dtype: int64
# 74

# %% [markdown]
# Всего 74 аномальных пользователей.

# %%
print('Относительная потеря пользователей после фильтрации, %', round(abnormalUsers.shape[0]*100/orders['visitorId'].nunique(), 3))
# Out:
# Относительная потеря пользователей после фильтрации, % 7.177

# %% [markdown]
# Чуть более 7% от общего количества уникальных пользователей составляют "аномальные пользователи".

# %% [markdown]
# Сформулируем гипотезы:
#
# **Нулевая:** различий в среднем количестве заказов на посетителя между группами А и В нет (*по "очищенным" данным*).
#
# **Альтернативная:** различия в среднем количестве заказов на посетителя между группами А и В есть (*по "очищенным" данным*).

# %%
sampleAF = pd.concat(
    [ordersByUsersA[np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))]['orders'],
    pd.Series(0, index=np.arange(visitorsAggregated[visitorsAggregated['group']=='A']['visitors'].max() 
                                 - len(ordersByUsersA['orders'])), name='orders')], axis=0)
sampleBF = pd.concat(
    [ordersByUsersB[np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))]['orders'],
    pd.Series(0, index=np.arange(visitorsAggregated[visitorsAggregated['group']=='B']['visitors'].max() 
                                 - len(ordersByUsersB['orders'])), name='orders')], axis=0)

# %%
print('P-value {0:.3f}'.format(stats.mannwhitneyu(sampleAF, sampleBF)[1]))
print('Относительный прирост среднего числа заказов группы B к группе А {0:.3f}'.format(sampleBF.mean()/sampleAF.mean() - 1))
# Out:
# P-value 0.013
# Относительный прирост среднего числа заказов группы B к группе А 0.173

# %% [markdown]
# **Вывод**
#
# Результаты теста на статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным практически не изменились по сравнению с аналогичным тестом с "сырыми" данными. Различия в группах есть.
#
# **Нулевую гипотезу о равенстве групп по числу заказов отвергаем.**
#
# Группа В показывает положительные результаты. "Очищенные" данные еще лучше показали увеличение среднего количества заказов на посетителя в группе В на 17.3%

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения

# %% [markdown]
# Сформулируем гипотезы:
#
# **Нулевая:** различий в среднем чеке заказа между группами А и В нет (*по "очищенным" данным*).
#
# **Альтернативная:** различия в среднем чеке заказа между группами А и В есть (*по "очищенным" данным*).

# %%
print('P-value {0:.3f}'.format(stats.mannwhitneyu(orders[np.logical_and(orders['group']=='A', np.logical_not(orders['visitorId'].isin(abnormalUsers)),)]['revenue'],
                                         orders[np.logical_and(orders['group']=='B', np.logical_not(orders['visitorId'].isin(abnormalUsers)),)]['revenue'],)[1]))
print('Относительный прирост среднего чека заказа группы B к группе А {0:.3f}'.format(orders[np.logical_and(orders['group']=='B', np.logical_not(orders['visitorId'].isin(abnormalUsers)),)]['revenue'].mean()/
                                         orders[np.logical_and(orders['group']=='A', np.logical_not(orders['visitorId'].isin(abnormalUsers)),)]['revenue'].mean() - 1))
# Out:
# P-value 0.738
# Относительный прирост среднего чека заказа группы B к группе А -0.020

# %% [markdown]
# **Вывод**
#
# Результаты по сравнению с "сырыми" данными практически не изменились: нулевую гипотезу не отвергаем и считаем, что в среднем чеке в двух группах нет отличий.
#
# Однако в ходе расчетов по "очищенным" данным относительные показатели группы В по среднему чеку отрицательные: на 2% ниже среднего чека в группе А. В "сырых" данных данный показатель был равень +25,9%.

# %% [markdown]
# ### Решение по результатам теста

# %% [markdown]
# Основные выводы по тесту:
#
# 1. По среднему количеству заказов на посетителя: есть статистически значимые различия между группами как по "сырым" данным, так и по "очищенным" от аномалий данным. Относительный "выигрыш" группы В зафиксированы также в обоих случаях: 13.3% и 17.3% после устранения аномальных значений.
# 2. По среднему чеку заказа: нет статистически значимых различий между группами ни по "сырым" данным, ни по "очищенным" от аномалий данным. В ходе расчетов по "очищенным" данным относительные показатели группы В по среднему чеку отрицательные: на 2% ниже среднего чека в группе А. В "сырых" данных данный показатель был равень +25,9%.
#
# **Исходя из обнаруженных фактов, тест следует остановить и зафиксировать победу группы В.**
#
# Данная группа показала высокие результаты по количеству заказов на посетителя. Показатели по среднему чеку практически не отличаются между группами. Относительный проигрыш группы В по среднему чеку заказа является статистически незначимым.
